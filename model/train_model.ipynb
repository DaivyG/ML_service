# %%
import pandas as pd

# %%
from params import engine

dfs = {}

tables = ['user_data', 'post_text_df']

for table in tables:
    dfs[table] = pd.read_sql(f'SELECT * FROM {table}', engine)

dfs['feed_data'] = pd.read_sql('SELECT * FROM feed_data LIMIT 2500000', engine)

# %%
category = {}

category['user_data'] = dfs['user_data'].select_dtypes(include='object').columns
category['post_text_df'] = dfs['post_text_df'].select_dtypes(include='object').columns

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

for table in tables:
    for col in category[table]:
        if col == 'text': # обработка колонки "текст"
            continue

        if len(dfs[table][col].unique()) <= 5:
            one_hot = pd.get_dummies(dfs[table][col], prefix=col, drop_first=True).astype(int)
            dfs[table] = pd.concat((dfs[table].drop(col, axis=1), one_hot), axis=1)
        else:
            dfs[table][col] = labelencoder.fit_transform(dfs[table][col])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA

tfidf = TfidfVectorizer(max_features=5000)

tfidf_matrix = tfidf.fit_transform(dfs['post_text_df']['text'])

pca = PCA(n_components=15)

pca_result = pca.fit_transform(tfidf_matrix.toarray())

# Создание DataFrame из результата PCA
pca_df = pd.DataFrame(
    data=pca_result,
    columns=[f'PC{i+1}' for i in range(pca_result.shape[1])],
    index=dfs['post_text_df'].index
)

# Объединение DataFrame с исходными данными
dfs['post_text_df'] = pd.concat([dfs['post_text_df'].drop('text', axis=1), pca_df], axis=1)

# %%
f_df = pd.merge(dfs['post_text_df'],
                dfs['feed_data'],
                on='post_id',
                how='inner')

# %%
df = pd.merge(f_df,
              dfs['user_data'],
              on='user_id',
              how='inner')
df.head(3)
# Out:
#    post_id  topic       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0        1      0 -0.126184 -0.235953  0.036757 -0.088046 -0.137950  0.001762
# 1     2370      1  0.269737 -0.015615  0.108110 -0.100946 -0.025815  0.149550
# 2     2376      1  0.279955  0.012463 -0.050199 -0.027545 -0.022602 -0.090940
#
#         PC7       PC8  ...  user_id  action  target  gender  age  country  \
# 0 -0.032423  0.047530  ...    65566    view       0       1   21        7
# 1  0.218116 -0.101648  ...    65566    view       0       1   21        7
# 2 -0.066211 -0.029931  ...    65566    view       1       1   21        7
#
#    city exp_group  os_iOS source_organic
# 0  1806         2       1              0
# 1  1806         2       1              0
# 2  1806         2       1              0
#
# [3 rows x 28 columns]

# %%
df = df[df['action'] != 'like']  # Удаляем строки, где action == 'like'

df = df.drop('action', axis=1) # ненужная колонка

# %%
# df['timestamp'] = pd.to_datetime(df['timestamp'])

# df['month'] = df['timestamp'].dt.month
# df['day'] = df['timestamp'].dt.day
# df['hour'] = df['timestamp'].dt.hour
# df['minute'] = df['timestamp'].dt.minute

# timestamp = df['timestamp']
df = df.drop('timestamp', axis=1)

# %%
df.head(5)
# Out:
#    post_id  topic       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0        1      0 -0.126184 -0.235953  0.036757 -0.088046 -0.137950  0.001762
# 1     2370      1  0.269737 -0.015615  0.108110 -0.100946 -0.025815  0.149550
# 2     2376      1  0.279955  0.012463 -0.050199 -0.027545 -0.022602 -0.090940
# 4       54      0 -0.001027 -0.138294 -0.075782 -0.092835 -0.087551 -0.015689
# 5     2386      1  0.334904 -0.036378  0.023209 -0.066104  0.007943  0.015516
#
#         PC7       PC8  ...      PC15  user_id  target  gender  age  country  \
# 0 -0.032423  0.047530  ...  0.125956    65566       0       1   21        7
# 1  0.218116 -0.101648  ... -0.039025    65566       0       1   21        7
# 2 -0.066211 -0.029931  ... -0.024126    65566       1       1   21        7
# 4 -0.013412  0.012524  ...  0.035853    65566       0       1   21        7
# 5 -0.055503 -0.090571  ...  0.032329    65566       0       1   21        7
#
#    city  exp_group  os_iOS  source_organic
# 0  1806          2       1               0
# 1  1806          2       1               0
# 2  1806          2       1               0
# 4  1806          2       1               0
# 5  1806          2       1               0
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['post_id', 'user_id', 'target'], axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=33,
                                                    shuffle=True)

# %%
# Пример распределения классов
class_counts = y_train.value_counts()
print(class_counts)

# Отношение классов
total = len(y_train)
class_ratios = {cls: count / total for cls, count in class_counts.items()}
print("Распределение классов:", class_ratios)
# Out:
# 0    1377273
# 1     186380
# Name: target, dtype: int64
# Распределение классов: {0: 0.8808047565540437, 1: 0.11919524344595636}

# %%
class_weights = [total / count for count in class_counts]

print("Веса классов:", class_weights)
# Out:
# Веса классов: [1.135325385744148, 8.389596523232106]

# %%
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe_catboost = Pipeline([('scaler', StandardScaler()),
                 ('catboost', CatBoostClassifier(max_depth=10,
                                                 iterations=1100,
                                                 l2_leaf_reg=3,
                                                 learning_rate=0.03,
                                                 class_weights=class_weights,
                                                 eval_metric='Precision',
                                                 early_stopping_rounds=100,
                                                 verbose=10))])

pipe_catboost.fit(X_train, y_train)
# Out:
# 0:	learn: 0.5663743	total: 335ms	remaining: 6m 8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 15
#       3 from sklearn.preprocessing import StandardScaler
#       5 pipe_catboost = Pipeline([('scaler', StandardScaler()),
#       6                  ('catboost', CatBoostClassifier(max_depth=10,
#       7                                                  iterations=1100,
#    (...)
#      12                                                  early_stopping_rounds=100,
#      13                                                  verbose=10))])
# ---> 15 pipe_catboost.fit(X_train, y_train)
#
# File ~/Рабочий стол/final_project/venv/lib/python3.8/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/Рабочий стол/final_project/venv/lib/python3.8/site-packages/catboost/core.py:5007, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5004 if 'loss_function' in params:
#    5005     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5007 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5008           eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
#    5009           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5010 return self
#
# File ~/Рабочий стол/final_project/venv/lib/python3.8/site-packages/catboost/core.py:2278, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2274 allow_clear_pool = train_params["allow_clear_pool"]
#    2276 with log_fixup(log_cout, log_cerr), \
#    2277     plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 2278     self._train(
#    2279         train_pool,
#    2280         train_params["eval_sets"],
#    2281         params,
#    2282         allow_clear_pool,
#    2283         train_params["init_model"]
#    2284     )
#    2286 # Have property feature_importance possibly set
#    2287 loss = self._object._get_loss_function_name()
#
# File ~/Рабочий стол/final_project/venv/lib/python3.8/site-packages/catboost/core.py:1705, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1704 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1705     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1706     self._set_trained_model_attributes()
#
# File _catboost.pyx:4585, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4634, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import classification_report


y_test_probs = pipe_catboost.predict_proba(X_test)[:, 1]
y_train_probs = pipe_catboost.predict_proba(X_train)[:, 1]

threshold = 0.58
y_test_preds_catboost = (y_test_probs >= threshold).astype(int)
y_train_preds_catboost = (y_train_probs >= threshold).astype(int)

print(classification_report(y_test, y_test_preds_catboost))
print(classification_report(y_train, y_train_preds_catboost))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85    590578
#            1       0.21      0.41      0.28     79788
#
#     accuracy                           0.75    670366
#    macro avg       0.56      0.60      0.56    670366
# weighted avg       0.83      0.75      0.78    670366
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85   1378523
#            1       0.23      0.46      0.31    185663
#
#     accuracy                           0.76   1564186
#    macro avg       0.58      0.63      0.58   1564186
# weighted avg       0.84      0.76      0.79   1564186

# %%
import os
import pickle

filename = 'catboost_model.pkl'

pickle.dump(pipe_catboost, open(filename, 'wb'))

def get_model_path(path: str) -> str:
    if (
        os.environ.get("IS_LMS") == "1"
    ):  # проверяем где выполняется код в лмс, или локально. Немного магии
        MODEL_PATH = "/workdir/user_input/model"
    else:
        MODEL_PATH = path
    return MODEL_PATH


def load_models():
    model_path = get_model_path("catboost_model.pkl")
    model = pickle.load(open(model_path, 'rb'))

    return model

model = load_models()
